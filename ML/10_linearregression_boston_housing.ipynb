# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget https://raw.githubusercontent.com/devdio/datasets/main/Boston.csv
# Out:
# --2024-01-04 06:01:50--  https://raw.githubusercontent.com/devdio/datasets/main/Boston.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35203 (34K) [text/plain]
# Saving to: ‘Boston.csv.1’
#
# Boston.csv.1        100%[===================>]  34.38K  --.-KB/s    in 0s
#
# 2024-01-04 06:01:50 (75.0 MB/s) - ‘Boston.csv.1’ saved [35203/35203]

# %%
boston = pd.read_csv('Boston.csv')

# %%
df = boston

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
df=df.drop('RAD',axis=1)
df=df.drop('NOX',axis=1)

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# LSTAT    506.0   12.653063    7.141062    1.73000    6.950000   11.36000
# PRICE    506.0   22.532806    9.197104    5.00000   17.025000   21.20000
#
#                 75%       max
# CRIM       3.677083   88.9762
# ZN        12.500000  100.0000
# INDUS     18.100000   27.7400
# CHAS       0.000000    1.0000
# RM         6.623500    8.7800
# AGE       94.075000  100.0000
# DIS        5.188425   12.1265
# TAX      666.000000  711.0000
# PTRATIO   20.200000   22.0000
# B        396.225000  396.9000
# LSTAT     16.955000   37.9700
# PRICE     25.000000   50.0000

# %%
X=df.drop('PRICE',axis=1)
X
# Out:
#         CRIM    ZN  INDUS  CHAS     RM   AGE     DIS  TAX  PTRATIO       B  \
# 0    0.00632  18.0   2.31     0  6.575  65.2  4.0900  296     15.3  396.90
# 1    0.02731   0.0   7.07     0  6.421  78.9  4.9671  242     17.8  396.90
# 2    0.02729   0.0   7.07     0  7.185  61.1  4.9671  242     17.8  392.83
# 3    0.03237   0.0   2.18     0  6.998  45.8  6.0622  222     18.7  394.63
# 4    0.06905   0.0   2.18     0  7.147  54.2  6.0622  222     18.7  396.90
# ..       ...   ...    ...   ...    ...   ...     ...  ...      ...     ...
# 501  0.06263   0.0  11.93     0  6.593  69.1  2.4786  273     21.0  391.99
# 502  0.04527   0.0  11.93     0  6.120  76.7  2.2875  273     21.0  396.90
# 503  0.06076   0.0  11.93     0  6.976  91.0  2.1675  273     21.0  396.90
# 504  0.10959   0.0  11.93     0  6.794  89.3  2.3889  273     21.0  393.45
# 505  0.04741   0.0  11.93     0  6.030  80.8  2.5050  273     21.0  396.90
#
#      LSTAT
# 0     4.98
# 1     9.14
# 2     4.03
# 3     2.94
# 4     5.33
# ..     ...
# 501   9.67
# 502   9.08
# 503   5.64
# 504   6.48
# 505   7.88
#
# [506 rows x 11 columns]

# %%
Y=df['PRICE']
Y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: PRICE, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y, test_size=0.25,random_state=0)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((379, 11), (127, 11), (379,), (127,))

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     RM   AGE     DIS  TAX  PTRATIO       B  \
# 0  0.00632  18.0   2.31     0  6.575  65.2  4.0900  296     15.3  396.90
# 1  0.02731   0.0   7.07     0  6.421  78.9  4.9671  242     17.8  396.90
# 2  0.02729   0.0   7.07     0  7.185  61.1  4.9671  242     17.8  392.83
# 3  0.03237   0.0   2.18     0  6.998  45.8  6.0622  222     18.7  394.63
# 4  0.06905   0.0   2.18     0  7.147  54.2  6.0622  222     18.7  396.90
#
#    LSTAT  PRICE
# 0   4.98   24.0
# 1   9.14   21.6
# 2   4.03   34.7
# 3   2.94   33.4
# 4   5.33   36.2

# %%
X_train.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS        RM       AGE       DIS  \
# CRIM     1.000000 -0.201351  0.391770 -0.052303 -0.185084  0.341526 -0.368217
# ZN      -0.201351  1.000000 -0.528755 -0.052096  0.327201 -0.584627  0.660710
# INDUS    0.391770 -0.528755  1.000000  0.046481 -0.395119  0.635201 -0.696408
# CHAS    -0.052303 -0.052096  0.046481  1.000000  0.081925  0.068587 -0.087921
# RM      -0.185084  0.327201 -0.395119  0.081925  1.000000 -0.248617  0.193052
# AGE      0.341526 -0.584627  0.635201  0.068587 -0.248617  1.000000 -0.760456
# DIS     -0.368217  0.660710 -0.696408 -0.087921  0.193052 -0.760456  1.000000
# TAX      0.571454 -0.327254  0.729234 -0.027192 -0.272416  0.508152 -0.532434
# PTRATIO  0.273101 -0.383914  0.377993 -0.092955 -0.370481  0.237848 -0.174499
# B       -0.311757  0.168671 -0.339950  0.075155  0.131769 -0.255566  0.262156
# LSTAT    0.459357 -0.428367  0.616902 -0.045924 -0.612997  0.615801 -0.516540
#
#               TAX   PTRATIO         B     LSTAT
# CRIM     0.571454  0.273101 -0.311757  0.459357
# ZN      -0.327254 -0.383914  0.168671 -0.428367
# INDUS    0.729234  0.377993 -0.339950  0.616902
# CHAS    -0.027192 -0.092955  0.075155 -0.045924
# RM      -0.272416 -0.370481  0.131769 -0.612997
# AGE      0.508152  0.237848 -0.255566  0.615801
# DIS     -0.532434 -0.174499  0.262156 -0.516540
# TAX      1.000000  0.449566 -0.427663  0.540966
# PTRATIO  0.449566  1.000000 -0.157012  0.383061
# B       -0.427663 -0.157012  1.000000 -0.388120
# LSTAT    0.540966  0.383061 -0.388120  1.000000

# %%
sns.heatmap(X_train.corr())
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

ss=StandardScaler()
X_train_s=ss.fit_transform(X_train)
X_train_s[:5]
# Out:
# array([[-0.3906002 ,  0.42637011, -0.74491444, -0.265747  , -1.02196078,
#          0.05196998,  1.99457086, -0.42799376,  0.27878885,  0.34049624,
#          0.82212111],
#        [-0.40127639,  0.5525335 , -0.84901832, -0.265747  , -0.55696276,
#         -0.76428645,  1.50565148, -0.69685273,  0.55287698,  0.42774893,
#         -0.46241699],
#        [-0.40110543,  1.18335044, -0.66648002,  3.76297754,  1.37812218,
#         -0.70040551,  0.4804933 , -0.87219554, -0.40643148,  0.34184377,
#         -0.90310809],
#        [ 0.6431195 , -0.49882807,  1.00060803, -0.265747  ,  0.22862396,
#          1.0669671 , -0.98282345,  1.53584571,  0.78128376,  0.37250012,
#          0.63583528],
#        [ 0.89986343, -0.49882807,  1.00060803, -0.265747  ,  0.67773696,
#          0.78305182, -0.9379895 ,  1.53584571,  0.78128376, -3.78699393,
#          1.84113239]])

# %%
Y_train=Y_train.values

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train_s,Y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-0.69117421,  0.99199843, -0.81388641,  0.67798567,  2.83558421,
#        -0.6663264 , -2.61921489, -0.60027582, -1.66103887,  0.71897005,
#        -3.67067464])

# %%
lr.intercept_
# Out:
# 22.608707124010554

# %%
X_test_s= ss.transform(X_test)

# %%
Y_pred = lr.predict(X_test_s)
Y_pred[:5]
# Out:
# array([26.53421345, 22.14620791, 28.18552241, 11.74045787, 20.68166051])

# %%
Y_test = Y_test.values

# %%
from sklearn.metrics import mean_squared_error

mse =mean_squared_error(Y_test,Y_pred)
print('mse:',mse)
print('RMSE:', np.sqrt(mse))
# Out:
# mse: 33.266021700070304
# RMSE: 5.767670387606274

# %%
plt.scatter(Y_test,Y_pred)
plt.xlabel('true')
plt.ylabel('pred')
plt.plot([0,40],[0,40],color='red')
plt.show()
